# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from vllm import LLM, SamplingParams

# %%
prompts = [
    "Hello, my name is",
    "The president of the United States is",
    "The capital of France is",
    "The future of AI is",
]
sampling_params = SamplingParams(temperature=0.8, top_p=0.95)

# %%
llm = LLM(model="Qwen/Qwen3-0.6B")
# Out:
# INFO 08-26 17:48:30 [api_utils.py:272] non-default args: {'disable_log_stats': True}
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# INFO 08-26 17:48:31 [model.py:672] Resolved architecture: Qwen3ForCausalLM
# INFO 08-26 17:48:31 [model.py:1965] Using max model len 40960
# INFO 08-26 17:48:31 [scheduler.py:242] Chunked prefill is enabled with max_num_batched_tokens=8192.
# INFO 08-26 17:48:31 [kernel.py:308] Final IR op priority after setting platform defaults: IrOpPriorityConfig(rms_norm=['native'], fused_add_rms_norm=['native'])
# (EngineCore pid=270017) INFO 08-26 17:48:34 [core.py:122] Initializing a V1 LLM engine (v0.28.0) with config: model='Qwen/Qwen3-0.6B', speculative_config=None, tokenizer='Qwen/Qwen3-0.6B', skip_tokenizer_init=False, tokenizer_mode=auto, revision=main, tokenizer_revision=main, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=40960, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, data_parallel_size=1, decode_context_parallel_size=1, dcp_comm_backend=ag_rs, disable_custom_all_reduce=False, quantization=None, quantization_config=None, enforce_eager=False, enable_return_routed_experts=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser='', reasoning_parser_plugin='', enable_in_reasoning=False), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None, kv_cache_metrics=False, kv_cache_metrics_sample=0.01, cudagraph_metrics=False, enable_layerwise_nvtx_tracing=False, enable_mfu_metrics=False, enable_mm_processor_stats=False, enable_logging_iteration_details=False, jit_monitor_mode='warn', jit_monitor_verbose=False), seed=0, served_model_name=Qwen/Qwen3-0.6B, enable_prefix_caching=True, enable_chunked_prefill=True, pooler_config=None, compilation_config={'mode': <CompilationMode.VLLM_COMPILE: 3>, 'debug_dump_path': None, 'cache_dir': '', 'compile_cache_save_format': 'binary', 'backend': 'inductor', 'custom_ops': ['none'], 'ir_enable_torch_wrap': True, 'splitting_ops': ['vllm::unified_attention_with_output', 'vllm::unified_mla_attention_with_output', 'vllm::mamba_mixer2', 'vllm::mamba_mixer', 'vllm::short_conv', 'vllm::linear_attention', 'vllm::qwen_gdn_attention_core', 'vllm::qwen_gdn_attention_core_fused_norm_packed', 'vllm::gdn_attention_core_xpu', 'vllm::olmo_hybrid_gdn_full_forward', 'vllm::sparse_attn_indexer', 'vllm::rocm_aiter_sparse_attn_indexer', 'vllm::deepseek_v4_attention', 'vllm::hpc_rope_norm_forward', 'vllm::unified_kv_cache_update', 'vllm::unified_mla_kv_cache_update'], 'compile_mm_encoder': False, 'cudagraph_mm_encoder': False, 'encoder_cudagraph_token_budgets': [], 'encoder_cudagraph_max_vision_items_per_batch': 0, 'encoder_cudagraph_max_frames_per_batch': None, 'compile_sizes': [], 'compile_ranges_endpoints': [8192], 'inductor_compile_config': {'enable_auto_functionalized_v2': False, 'combo_kernels': True, 'benchmark_combo_kernel': True}, 'inductor_passes': {}, 'cudagraph_mode': <CUDAGraphMode.FULL_AND_PIECEWISE: (2, 1)>, 'cudagraph_num_of_warmups': 1, 'cudagraph_capture_sizes': [1, 2, 4, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160, 168, 176, 184, 192, 200, 208, 216, 224, 232, 240, 248, 256, 272, 288, 304, 320, 336, 352, 368, 384, 400, 416, 432, 448, 464, 480, 496, 512], 'cudagraph_copy_inputs': False, 'cudagraph_specialize_lora': True, 'use_inductor_graph_partition': False, 'pass_config': {'fuse_norm_quant': False, 'fuse_act_quant': False, 'fuse_attn_quant': False, 'enable_sp': False, 'fuse_gemm_comms': False, 'fuse_allreduce_rms': False, 'enable_qk_norm_rope_fusion': False, 'fuse_rope_kvcache_cat_mla': False, 'fuse_act_padding': False, 'fuse_qk_norm_rope_kvcache': False}, 'max_cudagraph_capture_size': 512, 'dynamic_shapes_config': {'type': <DynamicShapesType.BACKED: 'backed'>, 'evaluate_guards': False, 'assume_32_bit_indexing': False}, 'local_cache_dir': None, 'fast_moe_cold_start': False, 'static_all_moe_layers': []}, kernel_config=KernelConfig(ir_op_priority=IrOpPriorityConfig(rms_norm=['native'], fused_add_rms_norm=['native']), enable_flashinfer_autotune=True, enable_cutedsl_warmup=True, enable_jit_warmup=True, enable_bf16x3_router_gemm=False, moe_backend='auto', linear_backend='auto')
# (EngineCore pid=270017) INFO 08-26 17:48:35 [parallel_state.py:1638] world_size=1 rank=0 local_rank=0 distributed_init_method=file:///tmp/vllm_dist_c9f267d916974359b39b67a9b4a447d8 backend=nccl
# (EngineCore pid=270017) INFO 08-26 17:48:35 [parallel_state.py:1982] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 0, EP rank N/A, EPLB rank N/A
# (EngineCore pid=270017) INFO 08-26 17:48:35 [gpu_worker.py:396] Using V2 Model Runner
# (EngineCore pid=270017) INFO 08-26 17:48:36 [model_runner.py:358] Loading model from scratch...
# (EngineCore pid=270017) INFO 08-26 17:48:36 [cuda.py:486] Using FLASH_ATTN attention backend out of potential backends: ['FLASH_ATTN', 'FLASHINFER', 'TRITON_ATTN', 'FLEX_ATTENTION'].
# (EngineCore pid=270017) INFO 08-26 17:48:36 [flash_attn.py:866] Using FlashAttention version 2
# (EngineCore pid=270017) INFO 08-26 17:48:37 [weight_utils.py:858] Filesystem type for checkpoints: EXT4. Checkpoint size: 1.40 GiB. Available RAM: 29.61 GiB.
# (EngineCore pid=270017) INFO 08-26 17:48:37 [weight_utils.py:881] Auto-prefetch is disabled because the filesystem (EXT4) is not a recognized network FS (NFS/Lustre). If you want to force prefetching, start vLLM with --safetensors-load-strategy=prefetch.
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards: 100% Completed | 1/1 [00:00<00:00,  3.11it/s]
# Loading safetensors checkpoint shards: 100% Completed | 1/1 [00:00<00:00,  3.09it/s]
# (EngineCore pid=270017)
# (EngineCore pid=270017) INFO 08-26 17:48:37 [default_loader.py:430] Loading weights took 0.34 seconds
# (EngineCore pid=270017) INFO 08-26 17:48:38 [model_runner.py:380] Model loading took 1.12 GiB memory and 2.275071 seconds
# (EngineCore pid=270017) INFO 08-26 17:48:38 [topk_topp_sampler.py:62] Using FlashInfer for top-p & top-k sampling.
# (EngineCore pid=270017) INFO 08-26 17:48:40 [caching.py:343] reconstructed serializable fn from standalone compile artifacts. num_artifacts=3 num_submods=29
# (EngineCore pid=270017) INFO 08-26 17:48:40 [decorators.py:311] Directly load AOT compilation from path /home/monster/.cache/vllm/torch_compile_cache/torch_aot_compile/9f6dadde26cb715d6a12e3ebfc84bdd1c04e72f01f6b561e3fbf1722d4a2a14c/rank_0_0/model
# (EngineCore pid=270017) INFO 08-26 17:48:40 [monitor.py:53] torch.compile took 1.49 s in total
# (EngineCore pid=270017) INFO 08-26 17:48:40 [monitor.py:81] Initial profiling/warmup run took 0.30 s
# (EngineCore pid=270017) INFO 08-26 17:48:41 [gpu_worker.py:578] Available KV cache memory: 12.74 GiB
# (EngineCore pid=270017) INFO 08-26 17:48:41 [kv_cache_utils.py:1869] GPU KV cache size: 119,264 tokens, Maximum concurrency for 40,960 tokens per request: 2.91x
# Capturing CUDA graphs (PIECEWISE): 100%|██████████| 51/51 [00:02<00:00, 23.38it/s]
# Capturing CUDA graphs (FULL): 100%|██████████| 35/35 [00:01<00:00, 29.28it/s]
# (EngineCore pid=270017) INFO 08-26 17:48:45 [model_runner.py:906] Graph capturing finished in 4 secs, took 0.44 GiB
# (EngineCore pid=270017) INFO 08-26 17:48:45 [gpu_worker.py:804] Free memory on device (15.16/15.61 GiB) on startup. Desired GPU memory utilization is (0.92, 14.36 GiB). Actual usage is 1.42 GiB for consumed memory (weights + non-torch), 0.2 GiB for peak activation, and 0.44 GiB for CUDAGraph memory. Replace gpu_memory_utilization config with `--kv-cache-memory=13045247120` (12.15 GiB) to fit into requested memory, or `--kv-cache-memory=13905684992` (12.95 GiB) to fully utilize gpu memory. Current kv cache memory in use is 12.74 GiB.
# (EngineCore pid=270017) INFO 08-26 17:48:46 [jit_monitor.py:85] Kernel JIT monitor activated; monitored JIT compilations during inference will use mode=warn.
# (EngineCore pid=270017) INFO 08-26 17:48:46 [torch_utils.py:262] Reducing Torch threads from 14 to 1 for serving. Set OMP_NUM_THREADS in the external environment to override.
# (EngineCore pid=270017) INFO 08-26 17:48:46 [core.py:347] init engine (profile, create kv cache, warmup model) took 8.51 s (compilation: 1.49 s)
# (EngineCore pid=270017) INFO 08-26 17:48:46 [kernel.py:308] Final IR op priority after setting platform defaults: IrOpPriorityConfig(rms_norm=['native'], fused_add_rms_norm=['native'])
# INFO 08-26 17:48:47 [hf.py:551] Detected the chat template content format to be 'string'. You can set `--chat-template-content-format` to override this.
# (EngineCore pid=270017) INFO 08-27 12:11:52 [core.py:1329] [shutdown] EngineCore: trigger received signal=SIGTERM
# (EngineCore pid=270017) INFO 08-27 12:11:52 [core.py:1465] [shutdown] EngineCore: start mode=abort timeout=0s
# (EngineCore pid=270017) INFO 08-27 12:11:52 [core.py:1496] [shutdown] EngineCore: request processing complete; starting resource teardown
# (EngineCore pid=270017) INFO 08-27 12:11:52 [core.py:1342] [shutdown] EngineCore: exiting busy loop

# %%
outputs = llm.generate(prompts, sampling_params=sampling_params)

for output in outputs:
    prompt = output.prompt
    generated_text = output.outputs[0].text
    print(f"Prompt: {prompt!r}, Generated text: {generated_text!r}")
# Out:
# Rendering prompts: 100%|██████████| 4/4 [00:00<00:00, 77.38it/s]
# Processed prompts: 100%|██████████| 4/4 [00:00<00:00, 39.26it/s, est. speed input: 220.72 toks/s, output: 641.92 toks/s]
# Prompt: 'Hello, my name is', Generated text: ' Elise. I am a 32-year-old female patient with no family'
# Prompt: 'The president of the United States is', Generated text: ' not the only president. The president of the United States is the only president.'
# Prompt: 'The capital of France is', Generated text: ' Paris, which is in the same geographical area as the capital of Spain. True'
# Prompt: 'The future of AI is', Generated text: ' promising and full of possibilities, but it is also a complex challenge. As technology'

# %%
llm
# Out:
# Qwen3ForCausalLM()(
#   (model): Qwen3Model()(
#     (embed_tokens): VocabParallelEmbedding(num_embeddings=151936, num_embeddings_per_partition=151936, embedding_dim=1024, org_vocab_size=151936, num_embeddings_padded=151936, tp_size=1)
#     (layers): ModuleList()(
#       (0-27): 28 x Qwen3DecoderLayer()(
#         (self_attn): Qwen3Attention()(
#           (qkv_proj): QKVParallelLinear(in_features=1024, output_features=4096, bias=False, tp_size=1, gather_output=False)
#           (o_proj): RowParallelLinear(in_features=2048, output_features=1024, bias=False, tp_size=1, reduce_results=True)
#           (rotary_emb): RotaryEmbedding(head_size=128, rotary_dim=128, max_position_embeddings=40960, base=1000000, is_neox_style=True)(
#             (apply_rotary_emb): ApplyRotaryEmb(is_neox_style=True, enable_fp32_compute=False)
#           )
#           (attn): Attention(head_size=128, num_heads=16, num_kv_heads=8, scale=0.08838834764831845, backend=FlashAttentionImpl)
#           (q_norm): RMSNorm(hidden_size=128, eps=1e-06)
#           (k_norm): RMSNorm(hidden_size=128, eps=1e-06)
#         )
#         (mlp): Qwen2MLP()(
#           (gate_up_proj): MergedColumnParallelLinear(in_features=1024, output_features=6144, bias=False, tp_size=1, gather_output=False)
#           (down_proj): RowParallelLinear(in_features=3072, output_features=1024, bias=False, tp_size=1, reduce_results=True)
#           (act_fn): SiluAndMul()
#         )
#         (input_layernorm): RMSNorm(hidden_size=1024, eps=1e-06)
#         (post_attention_layernorm): RMSNorm(hidden_size=1024, eps=1e-06)
#       )
#     )
#     (norm): RMSNorm(hidden_size=1024, eps=1e-06)
#   )
#   (lm_head): ParallelLMHead(num_embeddings=151936, num_embeddings_per_partition=151936, embedding_dim=1024, org_vocab_size=151936, num_embeddings_padded=151936, tp_size=1)
#   (logits_processor): LogitsProcessor(vocab_size=151936, org_vocab_size=151936, scale=1.0, logits_as_input=False)
# )
# INFO 08-27 12:11:53 [utils.py:615] [shutdown] Process manager: send sigterm to process EngineCore
# WARNING 08-27 12:11:53 [core_client.py:728] [shutdown] MPClient: engine core exited unexpectedly; starting cleanup
# INFO 08-27 12:11:53 [core_client.py:689] [shutdown] MPClient: start timeout=default
# INFO 08-27 12:11:53 [core_client.py:691] [shutdown] MPClient: stopping engine manager
# INFO 08-27 12:11:53 [core_client.py:693] [shutdown] MPClient: engine manager stopped
# INFO 08-27 12:11:53 [core_client.py:694] [shutdown] MPClient: cleaning up background resources
# INFO 08-27 12:11:53 [core_client.py:696] [shutdown] MPClient: complete
