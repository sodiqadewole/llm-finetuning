# %%
from warnings import filterwarnings
filterwarnings("ignore", category=UserWarning)


import torch
from trl import DPOConfig, DPOTrainer
from datasets import load_dataset

model_name = "Qwen/Qwen3-0.6B"
dataset_name = "trl-lib/ultrafeedback_binarized"

training_args = DPOConfig(
    per_device_train_batch_size=1,
    gradient_accumulation_steps=8,
    gradient_checkpointing=True,
    # fp16=True,
    max_length=512,
    model_init_kwargs={"dtype": torch.float16},
)

trainer = DPOTrainer(
    model=model_name,
    args=training_args,
    train_dataset=load_dataset(dataset_name, split="train"),
    eval_dataset=load_dataset(dataset_name, split="test").select(range(10)),
)
# Out:
# Loading weights: 100%|██████████| 311/311 [00:00<00:00, 526.99it/s]
# Dropping fully truncated examples from train dataset: 100%|██████████| 62135/62135 [00:01<00:00, 42919.69 examples/s]
# Dropping fully truncated examples from eval dataset: 100%|██████████| 10/10 [00:00<00:00, 3889.74 examples/s]
# Loading weights: 100%|██████████| 311/311 [00:00<00:00, 521.77it/s]

# %%
# Print the model architecture
trainer.model
# Out:
# Qwen3ForCausalLM(
#   (model): Qwen3Model(
#     (embed_tokens): Embedding(151936, 1024)
#     (layers): ModuleList(
#       (0-27): 28 x Qwen3DecoderLayer(
#         (self_attn): Qwen3Attention(
#           (q_proj): Linear(in_features=1024, out_features=2048, bias=False)
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=False)
#           (v_proj): Linear(in_features=1024, out_features=1024, bias=False)
#           (o_proj): Linear(in_features=2048, out_features=1024, bias=False)
#           (q_norm): Qwen3RMSNorm((128,), eps=1e-06)
#           (k_norm): Qwen3RMSNorm((128,), eps=1e-06)
#         )
#         (mlp): Qwen3MLP(
#           (gate_proj): Linear(in_features=1024, out_features=3072, bias=False)
#           (up_proj): Linear(in_features=1024, out_features=3072, bias=False)
#           (down_proj): Linear(in_features=3072, out_features=1024, bias=False)
#           (act_fn): SiLUActivation()
#         )
#         (input_layernorm): Qwen3RMSNorm((1024,), eps=1e-06)
#         (post_attention_layernorm): Qwen3RMSNorm((1024,), eps=1e-06)
#       )
#     )
#     (norm): Qwen3RMSNorm((1024,), eps=1e-06)
#     (rotary_emb): Qwen3RotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=1024, out_features=151936, bias=False)
# )

# %% [markdown]
# ### Train the model

# %%
trainer.train()
# Out:
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
#     <div>
#
#       <progress value='1374' max='21657' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 1374/21657 1:18:57 < 19:27:19, 0.29 it/s, Epoch 0.19/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>19.311488</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>32.573596</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>13.008533</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>18.273158</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>12.417387</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>16.504698</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>15.460625</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>14.038908</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>13.902832</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>16.994035</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>15.613882</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>15.218137</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>19.839227</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>19.038249</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>16.291853</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>18.681218</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>13.590729</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>15.064848</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>26.930371</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>48.278021</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>38.261151</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>20.304140</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>31.438538</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>19.699673</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>38.785355</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>55.097095</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>35.239740</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>31.060004</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>28.417075</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>36.448718</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>19.043810</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>25.999844</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>20.367407</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>22.963620</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>23.035815</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>33.752960</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>26.415891</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>15.996661</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>22.471722</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>33.835226</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>14.880400</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>13.332127</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>23.869472</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>14.034584</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>16.751787</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>29.536536</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>16.137378</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>21.710023</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>23.241698</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>28.361469</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>51.625391</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>42.917416</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>41.224429</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>33.565735</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>105.201819</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>213.412061</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>649.161328</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>2250.149219</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>1341.046484</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1194.729297</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>976.697852</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>656.618799</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>432.557129</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>1105.060645</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>1171.068555</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>1512.414258</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>1823.227930</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>1996.681250</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>1448.508301</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>1550.682422</td>
#     </tr>
#     <tr>
#       <td>710</td>
#       <td>1748.280469</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>2922.580469</td>
#     </tr>
#     <tr>
#       <td>730</td>
#       <td>2174.925977</td>
#     </tr>
#     <tr>
#       <td>740</td>
#       <td>2692.353906</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>1949.155469</td>
#     </tr>
#     <tr>
#       <td>760</td>
#       <td>1897.030078</td>
#     </tr>
#     <tr>
#       <td>770</td>
#       <td>1914.613477</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>1386.673340</td>
#     </tr>
#     <tr>
#       <td>790</td>
#       <td>609.306445</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>905.413672</td>
#     </tr>
#     <tr>
#       <td>810</td>
#       <td>810.445117</td>
#     </tr>
#     <tr>
#       <td>820</td>
#       <td>1030.401562</td>
#     </tr>
#     <tr>
#       <td>830</td>
#       <td>816.046777</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>1308.971484</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>1242.722754</td>
#     </tr>
#     <tr>
#       <td>860</td>
#       <td>1149.756445</td>
#     </tr>
#     <tr>
#       <td>870</td>
#       <td>1110.921289</td>
#     </tr>
#     <tr>
#       <td>880</td>
#       <td>1262.127051</td>
#     </tr>
#     <tr>
#       <td>890</td>
#       <td>1481.045898</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>1047.613379</td>
#     </tr>
#     <tr>
#       <td>910</td>
#       <td>1256.796191</td>
#     </tr>
#     <tr>
#       <td>920</td>
#       <td>853.163965</td>
#     </tr>
#     <tr>
#       <td>930</td>
#       <td>977.610059</td>
#     </tr>
#     <tr>
#       <td>940</td>
#       <td>654.061816</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>559.898291</td>
#     </tr>
#     <tr>
#       <td>960</td>
#       <td>694.439160</td>
#     </tr>
#     <tr>
#       <td>970</td>
#       <td>919.474414</td>
#     </tr>
#     <tr>
#       <td>980</td>
#       <td>562.565625</td>
#     </tr>
#     <tr>
#       <td>990</td>
#       <td>996.269922</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>898.588867</td>
#     </tr>
#     <tr>
#       <td>1010</td>
#       <td>1160.906641</td>
#     </tr>
#     <tr>
#       <td>1020</td>
#       <td>621.442480</td>
#     </tr>
#     <tr>
#       <td>1030</td>
#       <td>891.464258</td>
#     </tr>
#     <tr>
#       <td>1040</td>
#       <td>608.598730</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>849.522754</td>
#     </tr>
#     <tr>
#       <td>1060</td>
#       <td>729.661328</td>
#     </tr>
#     <tr>
#       <td>1070</td>
#       <td>813.748926</td>
#     </tr>
#     <tr>
#       <td>1080</td>
#       <td>945.903027</td>
#     </tr>
#     <tr>
#       <td>1090</td>
#       <td>745.877148</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>878.196973</td>
#     </tr>
#     <tr>
#       <td>1110</td>
#       <td>772.859863</td>
#     </tr>
#     <tr>
#       <td>1120</td>
#       <td>730.459375</td>
#     </tr>
#     <tr>
#       <td>1130</td>
#       <td>814.241113</td>
#     </tr>
#     <tr>
#       <td>1140</td>
#       <td>693.178467</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>656.317285</td>
#     </tr>
#     <tr>
#       <td>1160</td>
#       <td>608.768018</td>
#     </tr>
#     <tr>
#       <td>1170</td>
#       <td>628.772705</td>
#     </tr>
#     <tr>
#       <td>1180</td>
#       <td>677.120410</td>
#     </tr>
#     <tr>
#       <td>1190</td>
#       <td>554.140820</td>
#     </tr>
#     <tr>
#       <td>1200</td>
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.24it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.39it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 trainer.train()
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/transformers/trainer.py:1449, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1447 ctx = suppress_progress_bars() if args.push_to_hub else contextlib.nullcontext()
#    1448 with ctx:
# -> 1449     return inner_training_loop(
#    1450         args=args,
#    1451         resume_from_checkpoint=resume_from_checkpoint,
#    1452         trial=trial,
#    1453         ignore_keys_for_eval=ignore_keys_for_eval,
#    1454     )
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/transformers/trainer.py:1531, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1529 for epoch in range(epochs_trained, num_train_epochs):
#    1530     self.control = self.callback_handler.on_epoch_begin(self.args, self.state, self.control)
# -> 1531     self._run_epoch(
#    1532         model=model,
#    1533         epoch=epoch,
#    1534         train_dataloader=train_dataloader,
#    1535         steps_in_epoch=steps_in_epoch,
#    1536         num_update_steps_per_epoch=num_update_steps_per_epoch,
#    1537         trial=trial,
#    1538         ignore_keys_for_eval=ignore_keys_for_eval,
#    1539         start_time=start_time,
#    1540         resume_from_checkpoint=resume_from_checkpoint,
#    1541         epochs_trained=epochs_trained,
#    1542         steps_trained_in_current_epoch=steps_trained_in_current_epoch,
#    1543     )
#    1544     if self.control.should_training_stop:
#    1545         break
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/transformers/trainer.py:1759, in Trainer._run_epoch(self, model, epoch, train_dataloader, steps_in_epoch, num_update_steps_per_epoch, trial, ignore_keys_for_eval, start_time, resume_from_checkpoint, epochs_trained, steps_trained_in_current_epoch)
#    1757     sync_context = functools.partial(self.accelerator.no_sync, model=model)
#    1758 with sync_context():
# -> 1759     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    1761 if (
#    1762     self.args.logging_nan_inf_filter
#    1763     and not is_torch_xla_available()
#    1764     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    1765 ):
#    1766     # if loss is nan or inf simply add the average of previous logged losses
#    1767     self._tr_loss += self._tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/trl/trainer/dpo_trainer.py:1782, in DPOTrainer.training_step(self, *args, **kwargs)
#    1780 def training_step(self, *args, **kwargs):
#    1781     with self.maybe_activation_offload_context:
# -> 1782         return super().training_step(*args, **kwargs)
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/transformers/trainer.py:1961, in Trainer.training_step(***failed resolving arguments***)
#    1958 if self.accelerator.distributed_type == DistributedType.DEEPSPEED:
#    1959     kwargs["scale_wrt_gas"] = False
# -> 1961 self.accelerator.backward(loss, **kwargs)
#    1963 return loss.detach()
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/accelerate/accelerator.py:2850, in Accelerator.backward(self, loss, **kwargs)
#    2848     self.lomo_backward(loss, learning_rate)
#    2849 else:
# -> 2850     loss.backward(**kwargs)
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/_tensor.py:623, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     613 if has_torch_function_unary(self):
#     614     return handle_torch_function(
#     615         Tensor.backward,
#     616         (self,),
#    (...)    621         inputs=inputs,
#     622     )
# --> 623 torch.autograd.backward(
#     624     self, gradient, retain_graph, create_graph, inputs=inputs
#     625 )
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/autograd/__init__.py:395, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     390     retain_graph = create_graph
#     392 # The reason we repeat the same comment below is that
#     393 # some Python versions print out the first line of a multi-line function
#     394 # calls in the traceback and some print out the last line
# --> 395 _engine_run_backward(
#     396     tensors,
#     397     grad_tensors_,
#     398     retain_graph,
#     399     create_graph,
#     400     inputs_tuple,
#     401     allow_unreachable=True,
#     402     accumulate_grad=True,
#     403 )
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/autograd/graph.py:979, in _engine_run_backward(t_outputs, *args, **kwargs)
#     976 torch._C._stash_obj_in_tls("context", contextvars.copy_context())
#     978 try:
# --> 979     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     980         t_outputs, *args, **kwargs
#     981     )  # Calls into the C++ engine to run the backward pass
#     982 finally:
#     983     if attach_logging_hooks:
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
