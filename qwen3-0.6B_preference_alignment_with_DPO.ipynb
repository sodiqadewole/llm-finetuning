# %%
from warnings import filterwarnings
filterwarnings("ignore")


import torch
from trl import DPOConfig, DPOTrainer
from datasets import load_dataset

model_name = "Qwen/Qwen3-0.6B"
dataset_name = "trl-lib/ultrafeedback_binarized"

training_args = DPOConfig(
    per_device_train_batch_size=1,
    gradient_accumulation_steps=8,
    gradient_checkpointing=True,
    fp16=True,
    max_length=512,
    model_init_kwargs={"dtype": torch.float16},
)

trainer = DPOTrainer(
    model=model_name,
    args=training_args,
    train_dataset=load_dataset(dataset_name, split="train"),
    eval_dataset=load_dataset(dataset_name, split="test").select(range(10)),
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|██████████| 311/311 [00:00<00:00, 2124.07it/s]
# [W825 14:42:16.415779002 CUDACachingAllocator.cpp:3933] memory allocation failed with OOM on device 0 while trying to allocate 312475648 bytes (free: 155582464, total: 16757751808).
# [W825 14:42:16.417133647 CUDACachingAllocator.cpp:3933] memory allocation failed with OOM on device 0 while trying to allocate 312475648 bytes (free: 157679616, total: 16757751808).
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[2], line 17
#      13     max_length=512,
#      14     model_init_kwargs={"dtype": torch.float16},
#      15 )
#      16
# ---> 17 trainer = DPOTrainer(
#      18     model=model_name,
#      19     args=training_args,
#      20     train_dataset=load_dataset(dataset_name, split="train"),
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/trl/trainer/dpo_trainer.py:888, in DPOTrainer.__init__(self, model, ref_model, args, data_collator, train_dataset, eval_dataset, processing_class, compute_metrics, callbacks, optimizers, quantization_config, peft_config)
#     885     args.gradient_checkpointing_kwargs = args.gradient_checkpointing_kwargs or {}
#     886     args.gradient_checkpointing_kwargs.setdefault("use_reentrant", False)
# --> 888 super().__init__(
#     889     model=model,
#     890     args=args,
#     891     data_collator=data_collator,
#     892     train_dataset=train_dataset,
#     893     eval_dataset=eval_dataset,
#     894     processing_class=processing_class,
#     895     compute_metrics=compute_metrics,
#     896     callbacks=callbacks,
#     897     optimizers=optimizers,
#     898 )
#     900 # Initialize activation offloading context
#     901 if self.args.activation_offloading:
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/trl/trainer/base_trainer.py:74, in _BaseTrainer.__init__(self, *args, **kwargs)
#      73 def __init__(self, *args, **kwargs):
# ---> 74     super().__init__(*args, **kwargs)
#      75     self._send_telemetry()
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/transformers/trainer.py:486, in Trainer.__init__(self, model, args, data_collator, train_dataset, eval_dataset, processing_class, model_init, compute_loss_func, compute_metrics, callbacks, optimizers, optimizer_cls_and_kwargs, preprocess_logits_for_metrics)
#     480 # ---- 5. Device placement ----------------------------------------------------
#     481 # Bnb Quantized models don't support `.to` operation.
#     482 if (
#     483     self.place_model_on_device
#     484     and getattr(model, "quantization_method", None) != QuantizationMethod.BITS_AND_BYTES
#     485 ):
# --> 486     self._move_model_to_device(model, args.device)
#     488 # Force n_gpu to 1 to avoid DataParallel as MP will manage the GPUs
#     489 if self.is_model_parallel:
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/transformers/trainer.py:4457, in Trainer._move_model_to_device(self, model, device)
#    4453     logger.warning(
#    4454         "The model is already on multiple devices. Skipping the move to device specified in `args`."
#    4455     )
#    4456     return
# -> 4457 model = model.to(device)
#    4458 # Moving a model to an XLA device disconnects the tied weights, so we have to retie them.
#    4459 if self.args.parallel_mode == ParallelMode.TPU and hasattr(model, "tie_weights"):
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/transformers/modeling_utils.py:3746, in PreTrainedModel.to(self, *args, **kwargs)
#    3741     if dtype_present_in_args:
#    3742         raise ValueError(
#    3743             "You cannot cast a GPTQ model in a new `dtype`. Make sure to load the model using `from_pretrained` using the desired"
#    3744             " `dtype` by passing the correct `dtype` argument."
#    3745         )
# -> 3746 return super().to(*args, **kwargs)
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1383, in Module.to(self, *args, **kwargs)
#    1380         else:
#    1381             raise
# -> 1383 return self._apply(convert)
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:933, in Module._apply(self, fn, recurse)
#     931 if recurse:
#     932     for module in self.children():
# --> 933         module._apply(fn)
#     935 from torch._subclasses.fake_tensor import FakeTensor
#     937 def compute_should_use_set_data(tensor, tensor_applied) -> bool:
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:933, in Module._apply(self, fn, recurse)
#     931 if recurse:
#     932     for module in self.children():
# --> 933         module._apply(fn)
#     935 from torch._subclasses.fake_tensor import FakeTensor
#     937 def compute_should_use_set_data(tensor, tensor_applied) -> bool:
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:964, in Module._apply(self, fn, recurse)
#     960 # Tensors stored in modules are graph leaves, and we don't want to
#     961 # track autograd history of `param_applied`, so we have to use
#     962 # `with torch.no_grad():`
#     963 with torch.no_grad():
# --> 964     param_applied = fn(param)
#     965 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     967 # subclasses may have multiple child tensors so we need to use swap_tensors
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1369, in Module.to.<locals>.convert(t)
#    1362     if convert_to_format is not None and t.dim() in (4, 5):
#    1363         return t.to(
#    1364             device,
#    1365             dtype if t.is_floating_point() or t.is_complex() else None,
#    1366             non_blocking,
#    1367             memory_format=convert_to_format,
#    1368         )
# -> 1369     return t.to(
#    1370         device,
#    1371         dtype if t.is_floating_point() or t.is_complex() else None,
#    1372         non_blocking,
#    1373     )
#    1374 except NotImplementedError as e:
#    1375     if str(e) == "Cannot copy out of meta tensor; no data!":
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 298.00 MiB. GPU 0 has a total capacity of 15.61 GiB of which 150.38 MiB is free. Process 76897 has 15.01 GiB memory in use. Including non-PyTorch memory, this process has 188.00 MiB memory in use. Of the allocated memory 0 bytes is allocated by PyTorch, and 0 bytes is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)

# %%
trainer.train()
