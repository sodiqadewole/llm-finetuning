# %%
from warnings import filterwarnings
filterwarnings("ignore", category=UserWarning)

# train_distillation.py
from datasets import load_dataset
from trl import DistillationTrainer, DistillationConfig

dataset = load_dataset("trl-lib/ultrafeedback-prompt", split="train")

training_args = DistillationConfig(
    per_device_train_batch_size=1,
    gradient_accumulation_steps=8,
    gradient_checkpointing=True,
    fp16=True,
    num_train_epochs=1
)

trainer = DistillationTrainer(
    model="Qwen/Qwen2.5-0.
    ..5B-Instruct",
    teacher_model="Qwen/Qwen2.5-1.5B-Instruct",
    train_dataset=dataset,
    args=training_args,
)
trainer.train()
# Out:
# Loading weights: 100%|██████████| 290/290 [00:00<00:00, 413.18it/s]
# Loading weights: 100%|██████████| 338/338 [00:00<00:00, 445.72it/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
#     <div>
#
#       <progress value='572' max='4721' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 572/4721 2:09:02 < 15:39:20, 0.07 it/s, Epoch 0.12/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>0.357371</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.328017</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.345680</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.364301</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.345097</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.327390</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.320220</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.335932</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.316452</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.304369</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.331706</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.307924</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.300460</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.305946</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.314904</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.326987</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.311831</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.317967</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.327061</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.314398</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.309617</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.295435</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.330246</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.306220</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.320523</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.313241</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.316900</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.316737</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.311088</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.295960</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.323033</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.325815</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.311388</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.314781</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.316920</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.295900</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.300887</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.322772</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.302251</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.302706</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.320537</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.297265</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.307863</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.307173</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.289694</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.326814</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.298744</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.307468</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.324918</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.289535</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>0.313582</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>0.326045</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>0.304259</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.312032</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.275421</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>0.311701</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>0.326970</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards: 100%|██████████| 1/1 [00:01<00:00,  1.78s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 24
#      20     teacher_model="Qwen/Qwen2.5-1.5B-Instruct",
#      21     train_dataset=dataset,
#      22     args=training_args,
#      23 )
# ---> 24 trainer.train()
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/transformers/trainer.py:1449, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1447 ctx = suppress_progress_bars() if args.push_to_hub else contextlib.nullcontext()
#    1448 with ctx:
# -> 1449     return inner_training_loop(
#    1450         args=args,
#    1451         resume_from_checkpoint=resume_from_checkpoint,
#    1452         trial=trial,
#    1453         ignore_keys_for_eval=ignore_keys_for_eval,
#    1454     )
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/transformers/trainer.py:1531, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1529 for epoch in range(epochs_trained, num_train_epochs):
#    1530     self.control = self.callback_handler.on_epoch_begin(self.args, self.state, self.control)
# -> 1531     self._run_epoch(
#    1532         model=model,
#    1533         epoch=epoch,
#    1534         train_dataloader=train_dataloader,
#    1535         steps_in_epoch=steps_in_epoch,
#    1536         num_update_steps_per_epoch=num_update_steps_per_epoch,
#    1537         trial=trial,
#    1538         ignore_keys_for_eval=ignore_keys_for_eval,
#    1539         start_time=start_time,
#    1540         resume_from_checkpoint=resume_from_checkpoint,
#    1541         epochs_trained=epochs_trained,
#    1542         steps_trained_in_current_epoch=steps_trained_in_current_epoch,
#    1543     )
#    1544     if self.control.should_training_stop:
#    1545         break
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/transformers/trainer.py:1759, in Trainer._run_epoch(self, model, epoch, train_dataloader, steps_in_epoch, num_update_steps_per_epoch, trial, ignore_keys_for_eval, start_time, resume_from_checkpoint, epochs_trained, steps_trained_in_current_epoch)
#    1757     sync_context = functools.partial(self.accelerator.no_sync, model=model)
#    1758 with sync_context():
# -> 1759     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    1761 if (
#    1762     self.args.logging_nan_inf_filter
#    1763     and not is_torch_xla_available()
#    1764     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    1765 ):
#    1766     # if loss is nan or inf simply add the average of previous logged losses
#    1767     self._tr_loss += self._tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/trl/trainer/distillation_trainer.py:1483, in DistillationTrainer.training_step(self, model, inputs, num_items_in_batch)
#    1481 def training_step(self, model, inputs, num_items_in_batch):
#    1482     time_before = time.perf_counter()
# -> 1483     output = super().training_step(model, inputs, num_items_in_batch)
#    1484     self._step += 1
#    1485     time_after = time.perf_counter()
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/transformers/trainer.py:1931, in Trainer.training_step(self, model, inputs, num_items_in_batch)
#    1928     return loss_mb.reduce_mean().detach().to(self.args.device)
#    1930 with self.compute_loss_context_manager():
# -> 1931     loss = self.compute_loss(model, inputs, num_items_in_batch=num_items_in_batch)
#    1933 del inputs
#    1934 if (
#    1935     self.args.torch_empty_cache_steps is not None
#    1936     and self.state.global_step % self.args.torch_empty_cache_steps == 0
#    1937 ):
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/trl/extras/profiling.py:211, in profiling_decorator.<locals>.wrapper(self, *args, **kwargs)
#     209 if hasattr(self, "state") and hasattr(self, "args"):
#     210     with profiling_context(self, func.__name__):
# --> 211         return func(self, *args, **kwargs)
#     212 # For non-Trainer objects (e.g., VLLMGeneration), use ProfilingContext directly
#     213 elif hasattr(self, "accelerator"):
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/trl/trainer/distillation_trainer.py:1351, in DistillationTrainer.compute_loss(self, model, inputs, return_outputs, num_items_in_batch)
#    1347 # Route the whole loss (backbone + `lm_head` projection + JSD) through the DDP/FSDP wrapper via
#    1348 # `_forward_redirection`, so DDP.forward() fires `prepare_for_backward()` and FSDP/DeepSpeed keep the student's
#    1349 # sharded parameters (including the `lm_head`) materialized for the projection.
#    1350 unwrapped_student = self.accelerator.unwrap_model(model)
# -> 1351 loss, entropy_sum, num_valid_tokens = self._forward_redirection(
#    1352     model, unwrapped_student, self._compute_loss, unwrapped_student, inputs, num_items_in_batch
#    1353 )
#    1355 # Log the mean per-token student entropy (in nats). The reduction runs here, after `_forward_redirection`
#    1356 # returns, so the `gather_for_metrics` collective does not run inside the DDP/FSDP-wrapped forward (a hang/
#    1357 # ordering risk). The Liger path produces no entropy, so it logs none. Mirrors `SFTTrainer.compute_loss`.
#    1358 if entropy_sum is not None:
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/trl/models/utils.py:370, in _ForwardRedirection.__call__(self, wrapper_module, original_module, method, *args, **kwargs)
#     367 # Patch the original_module's forward so we can redirect the arguments back to the real method
#     368 original_module.forward = wrapped_forward  # type: ignore[method-assign]
# --> 370 wrapper_output = wrapper_module(*args, **kwargs)
#     371 self.on_after_outer_forward(wrapper_module, original_module)
#     372 return wrapper_output
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/trl/models/utils.py:363, in _ForwardRedirection.__call__.<locals>.wrapped_forward(*_args, **_kwargs)
#     361 original_module.forward = original_forward  # type: ignore[method-assign]
#     362 # Call the actual method e.g. `.training_step(...)`
# --> 363 out = method(*_args, **_kwargs)
#     364 self.on_after_inner_forward(wrapper_module, original_module)
#     365 return out
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/trl/trainer/distillation_trainer.py:1389, in DistillationTrainer._compute_loss(self, unwrapped_student, inputs, num_items_in_batch)
#    1377 multimodal_keys = (
#    1378     "pixel_values",
#    1379     "image_grid_thw",
#    (...)   1385     "image_position_ids",
#    1386 )
#    1387 multimodal_inputs = {k: inputs[k] for k in multimodal_keys if k in inputs}
# -> 1389 student_hidden_states = self._get_last_hidden_state(
#    1390     unwrapped_student, input_ids, attention_mask, logits_to_keep, **multimodal_inputs
#    1391 )
#    1393 # Route the teacher backbone through its own wrapper via `_forward_redirection` too, so FSDP/DeepSpeed
#    1394 # materialize its sharded parameters before the forward runs (the backbone call would otherwise see shards).
#    1395 self.teacher_model.eval()
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/trl/extras/profiling.py:211, in profiling_decorator.<locals>.wrapper(self, *args, **kwargs)
#     209 if hasattr(self, "state") and hasattr(self, "args"):
#     210     with profiling_context(self, func.__name__):
# --> 211         return func(self, *args, **kwargs)
#     212 # For non-Trainer objects (e.g., VLLMGeneration), use ProfilingContext directly
#     213 elif hasattr(self, "accelerator"):
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/trl/trainer/distillation_trainer.py:1150, in DistillationTrainer._get_last_hidden_state(self, unwrapped_model, input_ids, attention_mask, logits_to_keep, pixel_values, image_grid_thw, pixel_attention_mask, spatial_shapes, image_sizes, token_type_ids, mm_token_type_ids, image_position_ids)
#    1148 else:
#    1149     backbone = unwrapped_model.base_model
# -> 1150 last_hidden_state = backbone(**model_inputs).last_hidden_state
#    1151 # Exclude the last value: it corresponds to the next token pred
#    1152 last_hidden_state = last_hidden_state[:, :-1, :]  # (B, L-1, H)
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/transformers/utils/generic.py:1068, in merge_with_config_defaults.<locals>.wrapper(self, *args, **kwargs)
#    1066             output = func(self, *args, **kwargs)
#    1067     else:
# -> 1068         output = func(self, *args, **kwargs)
#    1069 # Restore original config value
#    1070 finally:
#    1071     if is_causal is not None:
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/transformers/utils/output_capturing.py:262, in capture_outputs.<locals>.wrapped_fn.<locals>.wrapper(self, *args, **kwargs)
#     260 # Run the forward
#     261 try:
# --> 262     outputs = func(self, *args, **kwargs)
#     263 # Reset the states
#     264 finally:
#     265     _active_collector.reset(output_token)
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/transformers/models/qwen2/modeling_qwen2.py:388, in Qwen2Model.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, **kwargs)
#     385 position_embeddings = self.rotary_emb(hidden_states, position_ids)
#     387 for i, decoder_layer in enumerate(self.layers[: self.config.num_hidden_layers]):
# --> 388     hidden_states = decoder_layer(
#     389         hidden_states,
#     390         attention_mask=causal_mask_mapping[self.config.layer_types[i]],
#     391         position_embeddings=position_embeddings,
#     392         position_ids=position_ids,
#     393         past_key_values=past_key_values,
#     394         use_cache=use_cache,
#     395         **kwargs,
#     396     )
#     398 hidden_states = self.norm(hidden_states)
#     399 return BaseModelOutputWithPast(
#     400     last_hidden_state=hidden_states,
#     401     past_key_values=past_key_values if use_cache else None,
#     402 )
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/transformers/modeling_layers.py:113, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#     110         message = message.rstrip(",") + "."
#     111         logger.warning_once(message)
# --> 113     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
#     114 return super().__call__(*args, **kwargs)
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/_compile.py:54, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      51     disable_fn = torch._dynamo.disable(fn, recursive, wrapping=False)
#      52     fn.__dynamo_disable = disable_fn  # type: ignore[attr-defined]
# ---> 54 return disable_fn(*args, **kwargs)
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:1446, in DisableContext.__call__.<locals>._fn(*args, **kwargs)
#    1438         with fx_traceback.annotate(
#    1439             {
#    1440                 "_torchdynamo_disable": True,
#    (...)   1443             }
#    1444         ):
#    1445             return fn(*args, **kwargs)
# -> 1446     return fn(*args, **kwargs)
#    1447 finally:
#    1448     set_eval_frame(None)
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/utils/checkpoint.py:522, in checkpoint(function, use_reentrant, context_fn, determinism_check, debug, early_stop, *args, **kwargs)
#     520 except BaseException as e:
#     521     try:
# --> 522         gen.throw(e)
#     523     except StopIteration as stop:
#     524         raise RuntimeError(
#     525             "torch.utils.checkpoint: the forward context provided by "
#     526             "context_fn suppressed an exception raised during the "
#     527             "checkpointed forward. This is not supported because "
#     528             "checkpoint cannot return a value for a failed forward."
#     529         ) from stop
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/utils/checkpoint.py:1706, in _checkpoint_without_reentrant_generator(fn, preserve_rng_state, context_fn, determinism_check, debug, early_stop, *args, **kwargs)
#    1704 with _checkpoint_hook(new_frame), forward_context:
#    1705     try:
# -> 1706         yield
#    1707     except BaseException:
#    1708         forward_context_suppressed_exc = True
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/utils/checkpoint.py:519, in checkpoint(function, use_reentrant, context_fn, determinism_check, debug, early_stop, *args, **kwargs)
#     517 next(gen)
#     518 try:
# --> 519     ret = function(*args, **kwargs)
#     520 except BaseException as e:
#     521     try:
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/transformers/models/qwen2/modeling_qwen2.py:296, in Qwen2DecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_values, use_cache, position_embeddings, **kwargs)
#     294 residual = hidden_states
#     295 hidden_states = self.post_attention_layernorm(hidden_states)
# --> 296 hidden_states = self.mlp(hidden_states)
#     297 hidden_states = residual + hidden_states
#     298 return hidden_states
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/transformers/models/qwen2/modeling_qwen2.py:47, in Qwen2MLP.forward(self, x)
#      46 def forward(self, x):
# ---> 47     down_proj = self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
#      48     return down_proj
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/nn/modules/linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# File ~/Desktop/codes/llm-finetuning/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1954, in Module.__getattr__(self, name)
#    1949         self._backward_pre_hooks = OrderedDict()
#    1951 # It is crucial that the return type is not annotated as `Any`, otherwise type checking
#    1952 # on `torch.nn.Module` and all its subclasses is largely disabled as a result. See:
#    1953 # https://github.com/pytorch/pytorch/pull/115074
# -> 1954 def __getattr__(self, name: str) -> Union[Tensor, "Module"]:
#    1955     if "_parameters" in self.__dict__:
#    1956         _parameters = self.__dict__["_parameters"]
#
# KeyboardInterrupt:
